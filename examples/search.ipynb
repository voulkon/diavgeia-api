# %%
! pip install diavgeia-api

# %%
from diavgeia_api import DiavgeiaClient

# Initialize client
client = DiavgeiaClient()

# We will recycle it throughout the notebook

# %%
response_of_dimos_thivas = client.search_decisions(
    org = "6115;dimosthivas",
    from_date = "2023-01-01",
    to_date = "2025-04-01",
)

# %%
response_of_dimos_thivas
# Out:
# SearchResponse(decisions=[Decision(protocolNumber='5684', subject='ΑΠΟΦΑΣΗ ΑΝΑΘΕΣΗΣ ΠΡΟΜΗΘΕΙΑΣ ΠΡΟΚΑΤΑΣΚΕΥΑΣΜΕΝΩΝ ΟΙΚΙΣΚΩΝ ΓΡΑΦΕΙΩΝ ΓΙΑ ΤΟ Ε.Ε.Ε.Κ. ΘΗΒΑΣ', issueDate=datetime.datetime(2025, 3, 31, 0, 0, tzinfo=TzInfo(UTC)), organizationId='6115', signerIds=['100048924'], unitIds=['100078457'], decisionTypeId='Δ.1', thematicCategoryIds=['20'], privateData=False, submissionTimestamp=datetime.datetime(2025, 3, 31, 10, 29, 11, 769000, tzinfo=TzInfo(UTC)), publishTimestamp=datetime.datetime(2025, 3, 31, 10, 29, 11, 769000, tzinfo=TzInfo(UTC)), status=<DecisionStatus.PUBLISHED: 'PUBLISHED'>, ada='9Χ3ΖΩΡΜ-ΩΓΦ', versionId='79820809-cae5-4512-9f6b-a480433915a9', correctedVersionId=None, documentUrl='https://diavgeia.gov.gr/doc/9Χ3ΖΩΡΜ-ΩΓΦ', documentChecksum=None, url='https://diavgeia.gov.gr/luminapi/api/decisions/9Χ3ΖΩΡΜ-ΩΓΦ', attachments=[], warnings=None, extraFieldValues=ExtraFieldValues(financialYear=None, budgettype=None, entryNumber=None, recalledExpenseDecision=None, amountWithVAT=Non
# ...

# %%
revoked_of_last_two_years = client.search_decisions(
    from_date = "2023-01-01",
    to_date = "2025-04-01",
    status = "REVOKED"
)

# %%
revoked_of_last_two_years
# Out:
# SearchResponse(decisions=[Decision(protocolNumber='4893/2025', subject='ΑΠΟΦΑΣΗ ΑΠΟΔΟΧΗΣ ΠΑΡΑΙΤΗΣΗΣ ΥΠΑΛΛΗΛΟΥ', issueDate=datetime.datetime(2025, 3, 31, 0, 0, tzinfo=TzInfo(UTC)), organizationId='6124', signerIds=['111870'], unitIds=['10754'], decisionTypeId='2.4.7.1', thematicCategoryIds=['10004'], privateData=False, submissionTimestamp=datetime.datetime(2025, 3, 31, 12, 9, 3, 189000, tzinfo=TzInfo(UTC)), publishTimestamp=datetime.datetime(2025, 3, 31, 8, 16, 16, 898000, tzinfo=TzInfo(UTC)), status=<DecisionStatus.REVOKED: 'REVOKED'>, ada='ΡΟΩΦΩΕ7-8Φ5', versionId='fb140a80-a209-42a4-9071-022de4af1921', correctedVersionId=None, documentUrl=None, documentChecksum=None, url='https://diavgeia.gov.gr/luminapi/api/decisions/ΡΟΩΦΩΕ7-8Φ5', attachments=[], warnings=None, extraFieldValues=ExtraFieldValues(financialYear=None, budgettype=None, entryNumber=None, recalledExpenseDecision=None, amountWithVAT=None, amountWithKae=None, partialead=None, relatedDecisions=[], documentType='ΠΡΑΞΗ')), Dec
# ...

# %%
# revoked_of_last_two_years = 
our_ocean_2024 = client.search_decisions(
    term = "Our Ocean 2024",
)

# %%
our_ocean_2024
# Out:
# SearchResponse(decisions=[Decision(protocolNumber='ΠΣ22/2025', subject='Απολογισμός Πεπραγμένων Περιφέρειας Βορείου Αιγαίου έτους 2024.', issueDate=datetime.datetime(2025, 3, 11, 0, 0, tzinfo=TzInfo(UTC)), organizationId='5003', signerIds=['118005'], unitIds=['84841'], decisionTypeId='Α.2', thematicCategoryIds=['10004'], privateData=False, submissionTimestamp=datetime.datetime(2025, 4, 15, 10, 34, 11, 165000, tzinfo=TzInfo(UTC)), publishTimestamp=datetime.datetime(2025, 4, 15, 10, 34, 11, 165000, tzinfo=TzInfo(UTC)), status=<DecisionStatus.PUBLISHED: 'PUBLISHED'>, ada='ΡΟΩ77ΛΩ-ΙΤΤ', versionId='7c00779c-a6e9-425c-84df-3ada0d534144', correctedVersionId=None, documentUrl='https://diavgeia.gov.gr/doc/ΡΟΩ77ΛΩ-ΙΤΤ', documentChecksum=None, url='https://diavgeia.gov.gr/luminapi/api/decisions/ΡΟΩ77ΛΩ-ΙΤΤ', attachments=[], warnings=None, extraFieldValues=ExtraFieldValues(financialYear=None, budgettype=None, entryNumber=None, recalledExpenseDecision=None, amountWithVAT=None, amountWithKae=None,
# ...

# %%
ucs = client.search_decisions(
    term = "Unlimited Creative Services",
)

# %%
ucs
# Out:
# SearchResponse(decisions=[Decision(protocolNumber='57917', subject='Απευθείας  ανάθεση της υπηρεσίας με τίτλο: «Δημιουργία επετειακού λογότυπου και παραγωγή ψηφιακού χρονολογίου για τον εορτασμό των 100 χρόνων του Δήμου Ιλίου»', issueDate=datetime.datetime(2024, 11, 22, 0, 0, tzinfo=TzInfo(UTC)), organizationId='6123', signerIds=['100004859'], unitIds=['78721'], decisionTypeId='Δ.1', thematicCategoryIds=['20'], privateData=False, submissionTimestamp=datetime.datetime(2024, 11, 22, 11, 29, 36, 163000, tzinfo=TzInfo(UTC)), publishTimestamp=datetime.datetime(2024, 11, 22, 11, 29, 36, 163000, tzinfo=TzInfo(UTC)), status=<DecisionStatus.PUBLISHED: 'PUBLISHED'>, ada='ΨΙΛ1ΩΕΒ-ΑΔ0', versionId='efd4983c-cfc3-4b06-b4dc-9c3437e66d98', correctedVersionId=None, documentUrl='https://diavgeia.gov.gr/doc/ΨΙΛ1ΩΕΒ-ΑΔ0', documentChecksum=None, url='https://diavgeia.gov.gr/luminapi/api/decisions/ΨΙΛ1ΩΕΒ-ΑΔ0', attachments=[], warnings=None, extraFieldValues=ExtraFieldValues(financialYear=None, budgettype
# ...
